# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/admin/OneDrive/Desktop/crimeDatasets/crime/01_District_wise_crimes_committed_IPC_2001_2012.csv")
df
# Out:
#             STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0     ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1     ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2     ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3     ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4     ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
# ...              ...            ...   ...     ...                ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012       0                  0
# 9013     LAKSHADWEEP          TOTAL  2012       0                  0
# 9014      PUDUCHERRY       KARAIKAL  2012       5                  6
# 9015      PUDUCHERRY     PUDUCHERRY  2012      24                 21
# 9016      PUDUCHERRY          TOTAL  2012      29                 27
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# ...

# %%
len(df)
# Out:
# 9017

# %%
df.shape
# Out:
# (9017, 33)

# %%
df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
#        'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES'],
#       dtype='object')

# %% [markdown]
# <h2>lets check for any missing values</h2>

# %%
df.isnull()
# Out:
#       STATE/UT  DISTRICT   YEAR  MURDER  ATTEMPT TO MURDER  \
# 0        False     False  False   False              False
# 1        False     False  False   False              False
# 2        False     False  False   False              False
# 3        False     False  False   False              False
# 4        False     False  False   False              False
# ...        ...       ...    ...     ...                ...
# 9012     False     False  False   False              False
# 9013     False     False  False   False              False
# 9014     False     False  False   False              False
# 9015     False     False  False   False              False
# 9016     False     False  False   False              False
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER   RAPE  CUSTODIAL RAPE  \
# 0                                         False  False           False
# 1                                         False  False           False
# ...

# %%
features=['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
       'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
       'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
       'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
       'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
       'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
       'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
       'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
       'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
       'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
       'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
       'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES']

# %%
for feature in features:
    null_check=pd.isnull(df[feature])
    print(df[null_check])
# Out:
# Empty DataFrame
# Columns: [STATE/UT, DISTRICT, YEAR, MURDER, ATTEMPT TO MURDER, CULPABLE HOMICIDE NOT AMOUNTING TO MURDER, RAPE, CUSTODIAL RAPE, OTHER RAPE, KIDNAPPING & ABDUCTION, KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS, KIDNAPPING AND ABDUCTION OF OTHERS, DACOITY, PREPARATION AND ASSEMBLY FOR DACOITY, ROBBERY, BURGLARY, THEFT, AUTO THEFT, OTHER THEFT, RIOTS, CRIMINAL BREACH OF TRUST, CHEATING, COUNTERFIETING, ARSON, HURT/GREVIOUS HURT, DOWRY DEATHS, ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY, INSULT TO MODESTY OF WOMEN, CRUELTY BY HUSBAND OR HIS RELATIVES, IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES, CAUSING DEATH BY NEGLIGENCE, OTHER IPC CRIMES, TOTAL IPC CRIMES]
# Index: []
#
# [0 rows x 33 columns]
# Empty DataFrame
# ...

# %%
df=df.dropna()
df.shape
# Out:
# (9017, 33)

# %% [markdown]
# <h1>Murder<h1>

# %%
df['MURDER'].unique()
# Out:
# array([ 101,  151,   80,   82,    3,  182,  111,  162,   93,   65,  133,
#         157,  122,   89,  106,  102,  214,    6,   38,   53,    2,   58,
#          22,   33,  158,   77, 2602,   11,    4,   16,    7,    1,    5,
#           8,   83,   64,   45,    0,   52,   61,   15,  110,   13,   28,
#          71,   18,   40,   37,   32,   87,   26,   20,   17,   95,   79,
#          59,   86,  107, 1356,   47,   74,   34,  124,   66,   41,  128,
#         135,   56,  200,   67,   73,   60,   72,   25,   35,  114,   51,
#         153,  208,   36,  434,   24,  104,  127,  137,  116, 3643,   99,
#           9,   14,   76,   48,   31,   19,   50,   92,  105,  880,   90,
#          55,   42,   29,   30,   98,   62,   44, 1226,   68,   69,   12,
#          43,   21,   57,  781,  119,  144,   78,   27,   39,  141,  100,
#          46,   63, 1075,   70,  109,   97,  136,   81,   54,  243,   49,
#        1507,  221,  120,   23, 1626,  472,   84,  103,   88, 2425,  295,
# ...

# %%
df.groupyby('MURDER').size().reset_index(name='Numbers')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12104\4233093934.py in ?()
# ----> 1 df.groupyby('MURDER').size().reset_index(name='Numbers')
#
# ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'groupyby'
